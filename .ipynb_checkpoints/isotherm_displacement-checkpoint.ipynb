# %% [markdown]
# # Read UOP mooring data and analyze isothermal displacements
#
#
# The goal is to examine intermittency of internal waves.  The inital plan is to:
# - Load WHOI Upper Ocean Processes Group mooring data
# - Compute isothermal displacement at some depth in the permanent thermocline
# - Using Stratus mooring data to start
#
# Started 11/23/2021
#
# @jtomfarrar

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from scipy import signal
import datetime
import gsw

################
# This allows us to import Tom_tools
import sys
sys.path.append('../Tom_tools/') # you may need to adjust this path
import Tom_tools_v1 as tt
################

# %%
# %matplotlib inline
# %matplotlib qt5

plt.rcParams['figure.dpi'] = 100
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams['savefig.dpi'] = 500
plt.close('all')

__figdir__ = "./plots/"
savefig_args = {'bbox_inches':'tight', 'pad_inches':0.2}
plotfiletype='png'

# %%
# plt.rcParams

# %%
base_url = 'https://dods.ndbc.noaa.gov/thredds/dodsC/oceansites/DATA/Stratus/'
filename = 'OS_Stratus_2008_D_TS.nc'

url = base_url+filename

# %%
ds = xr.open_dataset(url)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (DEPTH: 16, LATITUDE: 1, LONGITUDE: 1, TIME: 129139)
# Coordinates:
#   * TIME        (TIME) datetime64[ns] 2008-10-26 ... 2010-01-17T09:30:00.0000...
#   * DEPTH       (DEPTH) float64 0.85 3.7 6.75 16.0 ... 190.0 220.0 250.0 310.0
#   * LATITUDE    (LATITUDE) float64 -19.71
#   * LONGITUDE   (LONGITUDE) float64 -85.59
# Data variables:
#     INST        int32 ...
#     INST_MFGR   (DEPTH) |S64 ...
#     INST_MODEL  (DEPTH) |S64 ...
#     INST_SN     (DEPTH) int32 ...
#     INST_URL    (DEPTH) |S64 ...
#     TEMP        (TIME, DEPTH) float64 ...
#     CNDC        (TIME, DEPTH) float64 ...
#     PSAL        (TIME, DEPTH) float64 ...
# Attributes:
#     data_type:                       OceanSites time-series data
#     Conventions:                     CF 1.6, OceanSITES-1.2
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     netcdf_version:                  3.5
#     format_version:                  1.2
#     institution:                     WHOI
#     source:                          Mooring observation
#     naming_authority:                OceanSITES
#     cdm_data_type:                   timeSeriesProfile
#     data_assembly_center:            WHOI-UOP
#     qc_manual:                       OceanSITES Users Manual v1.2
#     distribution_statement:           Follows CLIVAR (Climate Varibility and ...
#     license:                          Follows CLIVAR (Climate Varibility and ...
#     institution_references:          http://uop.whoi.edu
#     keywords_vocabulary:             GCMD Science Keywords
#     keywords:                        EARTH SCIENCE > Oceans > Salinity/Densit...
#     keywords_vocabulary_URL:         http://gcmd.nasa.gov/Resources/valids/ar...
#     standard_name_vocabulary:        CF-1.6
#     site_code:                       STRATUS
#     title:                           Ocean salinity data from surface mooring...
#     project:                         Stratus
#     platform_code:                   Stratus
#     wmo_platform_code:               38400
#     deplyment_number:                9
#     deployment_code:                 2008
#     id:                              OS_Stratus_2008_D_TS
#     summary:                         Delayed mode salinity data from the WHOI...
#     references:                      http://www.oceansites.org, http://uop.wh...
#     citation:                        Data provided by the Upper Ocean Process...
#     acknowledgment:                  Support for this research was provided b...
#     creator_name:                    Robert Weller
#     creator_url:                     http://www.whoi.edu/profile/rweller/
#     creator_email:                   rweller AT whoi.edu
#     pi_name:                         Robert Weller
#     principal_investigator:          Robert Weller
#     author:                          Kelan Huang
#     contact:                         ngalbraith@whoi.edu
#     publisher_name:                  WHOI Upper Ocean Processes Group (N. Gal...
#     publisher_url:                   http://uop.whoi.edu http://www.whoi.edu/...
#     publisher_email:                 UOP_DM@whoi.edu
#     contributor_name:                Kelan Huang
#     contributor_role:                Quality control, editing, data processing
#     date_created:                    2012-04-09T10:44:37Z
#     date_modified:                   2012-04-09T10:44:37Z
#     date_issued:                     2012-04-09T10:44:36Z
#     date_update:                     2012-04-09T10:44:37Z
#     update_interval:                 void
#     history:                         Buoy data processed by K.Huang
#     comment:                         Combined data from instruments on surfac...
#     data_mode:                       D
#     Metadata_Link:                   http://uop.whoi.edu/projects/Stratus/OS_...
#     quality_index:                   excellent
#     quality_control_procedure:       Data manually reviewed, clock drift corr...
#     QC_manual:                       http://www.oceansites.org/data/quality_c...
#     processing_level:                Drift corrections, post-calibrations, de...
#     area:                            Eastern Tropical Pacific
#     sea_name:                        South Pacific Ocean
#     water_depth:                     4529.0m
#     watch_circle:                    3.7nM
#     geospatial_lat_min:              -20
#     geospatial_lat_max:              -19
#     geospatial_lat_units:            degrees_north
#     geospatial_lat_resolution:       point
#     geospatial_lon_min:              -86
#     geospatial_lon_max:              -85
#     geospatial_lon_units:            degrees_east
#     geospatial_lon_resolution:       point
#     geospatial_vertical_min:         -1
#     geospatial_vertical_max:         3
#     geospatial_vertical_units:       meters
#     geospatial_vertical_positive:    down
#     geospatial_vertical_resolution:  point
#     time_coverage_start:             2000-10-07T22:15:01Z
#     time_coverage_end:               2001-10-17T11:52:31Z
#     time_coverage_duration:          P448D
#     time_coverage_resolution:        P5.00M
#     DODS.strlen:                     90
#     DODS.dimName:                    strlen3

# %%
T = ds.TEMP.values

# %%
ds.LATITUDE
# Out:
# <xarray.DataArray 'LATITUDE' (LATITUDE: 1)>
# array([-19.710743])
# Coordinates:
#   * LATITUDE  (LATITUDE) float64 -19.71
# Attributes:
#     long_name:                   Mooring anchor latitude
#     standard_name:               latitude
#     units:                       degrees_north
#     valid_min:                   -19.710743333333333
#     valid_max:                   -19.710743333333333
#     reference:                   WGS84
#     coordinate_reference_frame:  urn:ogc:crs:EPSG::4326
#     uncertainty:                 0.01
#     axis:                        Y
#     comment:                     surveyed anchor position

# %%
fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(111)
cs = plt.contourf(ds.TIME, ds.DEPTH, T.transpose(),10, cmap=plt.cm.turbo)
ax.invert_yaxis()
for z in ds.DEPTH:
    plt.plot(ds.TIME[0], z, 'ko', clip_on=False)
cb = plt.colorbar(cs,fraction = 0.022)
cb.set_label('T [$\circ$C]',fontsize = 10)
    
plt.title('T at Stratus site')
plt.ylabel('Depth [m]')
# Out:
# Text(0, 0.5, 'Depth [m]')

# %%
ds['DEPTH'][12:16]
# Out:
# <xarray.DataArray 'DEPTH' (DEPTH: 4)>
# array([190., 220., 250., 310.])
# Coordinates:
#   * DEPTH    (DEPTH) float64 190.0 220.0 250.0 310.0
# Attributes:
#     long_name:                   measurement depth
#     standard_name:               depth
#     units:                       meters
#     positive:                    down
#     valid_min:                   0.85
#     valid_max:                   310.0
#     reference:                   mean_sea_level
#     coordinate_reference_frame:  urn:ogc:crs:EPSG::5113
#     axis:                        Z
#     comment:                     approximate instrument depth

# %%
zind = 13
#
# Plotting
#
fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(111)
#plt.plot(time,vel_e[N//2:-N//2+1],label='IMU vel.')
plt.plot(ds['TIME'],ds['TEMP'][:,zind])
#plt.xlim(datetime.datetime(2019,4,25,12,43,0),datetime.datetime(2019,4,25,12,44,0))
#plt.ylim(-0.6,1.2)
#plt.xlabel('April 25, 2019')
plt.title('T at '+str(ds['DEPTH'][zind].values) + ' m')
plt.ylabel('T [$^\circ$C]')
# plt.savefig(__figdir__+'rain.pdf',**savefig_args)
# Out:
# Text(0, 0.5, 'T [$^\\circ$C]')

# %% [markdown]
# ## Now compute $\zeta$
#
#
# Use $\zeta = \frac{T^\prime}{ \partial \bar{T} / \partial z}$
#
# where the bar is a 10-day average

# %%
dT = ds['TEMP'][:,zind-1]-ds['TEMP'][:,zind+1]
dz = -(ds['DEPTH'][zind-1]-ds['DEPTH'][zind+1])
dT_dz = dT/dz.values

# %%
np.shape(dT_dz)
# Out:
# (129139,)

# %%
dTbar_dz = tt.run_avg1d(dT_dz.values, 12*24*10)

# %%
Tprime = ds['TEMP'][:,zind] - tt.run_avg1d(ds['TEMP'][:,zind], 12*24*10)

# %%
zeta = Tprime/dTbar_dz

# %%
fig = plt.figure(figsize=(6,6))
ax1 = fig.add_subplot(411)
plt.plot(ds['TIME'],ds['TEMP'][:,zind])
plt.title('T at '+str(ds['DEPTH'][zind].values) + ' m')
plt.ylabel('T [$^\circ$C]')

ax2 = fig.add_subplot(412)
plt.plot(ds['TIME'],dTbar_dz)
plt.ylabel('dT/dz')

ax3 = fig.add_subplot(413)
plt.plot(ds['TIME'],Tprime)
plt.ylabel('T$^\prime$')
plt.ylim([-3, 3])

ax4 = fig.add_subplot(414)
plt.plot(ds['TIME'],zeta)
plt.ylabel('$\zeta$ [m]')
plt.ylim([-30, 30])


fig.autofmt_xdate()

# %%
# use tt.spectrum_band_avg(yy,dt,M,winstr=None,plotflag=None,ebarflag=None)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
M = 17
winstr = 'hann'
dt = 5/60/24
yy = zeta.values

tt.spectrum_band_avg(yy,dt,M,winstr=None,plotflag=True,ebarflag=None);
ax.set_xlabel('Frequency [cpd]')
ax.set_ylabel('Spectral density [m$^2$/cpd]')
# Out:
# Text(0, 0.5, 'Spectral density [m$^2$/cpd]')

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
L=12*24*10
M = 31
YY=[]
YY_time=[]
ind = np.arange(0,len(zeta.values)-L,12*24)
for n in np.arange(0,len(ind)-1):
    yy = zeta[ind[n]:ind[n]+L].values
    if n==0:
        # tt.spectrum_band_avg(yy,dt,M,winstr=None,plotflag=True,ebarflag=True)
        YY_avg, freq, EDOF = tt.spectrum_band_avg(yy,dt,M,winstr=None,plotflag=True,ebarflag=True)
        YY = np.reshape(YY_avg,(YY_avg.size,1))
    else:
        # tt.spectrum_band_avg(yy,dt,M,winstr=None,plotflag=True,ebarflag=False)
        YY_avg, freq, EDOF = tt.spectrum_band_avg(yy,dt,M,winstr=None,plotflag=True,ebarflag=False)
        YY=np.append(YY,np.reshape(YY_avg,(YY_avg.size,1)),axis=1)        

YY_time= np.arange(0,len(ind)-1)
        
ax.set_xlabel('Frequency [cpd]')
ax.set_ylabel('Spectral density [m$^2$/cpd]')
# Out:
# Text(0, 0.5, 'Spectral density [m$^2$/cpd]')

# %%
f = gsw.geostrophy.f(np.abs(ds.LATITUDE.values[0]))
inertial_period = 2*np.pi/f/3600
print('Latitude is '+ f'{ds.LATITUDE.values[0]:.1f}')
print('Inertial period is '+ f'{inertial_period:.1f}' + ' hours')
f_cpd=f*3600*24/(2*np.pi)
M2_cpd=24/12.42
# Out:
# Latitude is -19.7
# Inertial period is 35.5 hours

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
cs = plt.contourf(YY_time, freq, np.log10(YY), 30, cmap=plt.cm.turbo)
plt.semilogy()
plt.semilogy(YY_time,0.*YY_time+f_cpd,'k--')
plt.semilogy(YY_time,0.*YY_time+M2_cpd,'k-')
cb = plt.colorbar(cs,fraction = 0.022)
cb.set_label('log$_{10}$($\Psi$)',fontsize = 10)
    
plt.title('Spectrogram')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')
